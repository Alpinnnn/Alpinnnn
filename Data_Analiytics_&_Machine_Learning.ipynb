# %% [markdown]
# <a href="https://colab.research.google.com/github/Alpinnnn/Alpinnnn/blob/main/Data_Analiytics_%26_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'Nama': ['John', 'Anna', 'Peter', 'Linda'],
        "Usia": [28, 35, 40, 32],
        "Kota": ['New York', 'Paris', 'Berlin', 'London']}

df = pd.DataFrame(data)
df.head()
# Out:
#     Nama  Usia      Kota
# 0   John    28  New York
# 1   Anna    35     Paris
# 2  Peter    40    Berlin
# 3  Linda    32    London

# %%
import pandas as pd

# %%
student_data = pd.read_csv('student_data.csv')

# %%
student_data.head(3)
# Out:
#                Name Group      Height     Weight Date_of_Birth  \
# 0      Alan Ferrell     A  131.433702  62.469138    2005-10-06
# 1    Lindsay Coffey     B  160.972880  44.525710    2005-12-21
# 2  Mitchell Bennett     A  132.967250  93.559249    2005-08-30
#
#    Maths_Test_Score  Maths_Quiz_Score  Maths_Assignment_Score  \
# 0                75                23                      96
# 1                26                95                      93
# 2                51                93                      89
#
#    Science_Test_Score  Science_Quiz_Score  Science_Assignment_Score  \
# 0                  88                   1                         2
# 1                  73                  57                        10
# 2                  56                  36                         8
#
#    Literature_Test_Score  Literature_Quiz_Score  Literature_Assignment_Score
# 0                     78                     51                           60
# ...

# %%
student_data.size
# Out:
# 4200

# %%
student_data.shape
# Out:
# (300, 14)

# %%
student_data.columns
# Out:
# Index(['Name', 'Group', 'Height', 'Weight', 'Date_of_Birth',
#        'Maths_Test_Score', 'Maths_Quiz_Score', 'Maths_Assignment_Score',
#        'Science_Test_Score', 'Science_Quiz_Score', 'Science_Assignment_Score',
#        'Literature_Test_Score', 'Literature_Quiz_Score',
#        'Literature_Assignment_Score'],
#       dtype='object')

# %%
student_data.iloc[2]
# Out:
# Name                           Mitchell Bennett
# Group                                         A
# Height                                132.96725
# Weight                                93.559249
# Date_of_Birth                        2005-08-30
# Maths_Test_Score                             51
# Maths_Quiz_Score                             93
# Maths_Assignment_Score                       89
# Science_Test_Score                           56
# Science_Quiz_Score                           36
# Science_Assignment_Score                      8
# Literature_Test_Score                         6
# Literature_Quiz_Score                        18
# Literature_Assignment_Score                   5
# Name: 2, dtype: object

# %%
student_data.iloc[100:121]
# Out:
#                   Name Group      Height     Weight Date_of_Birth  \
# 100  Mr. William Brown     B  182.620124  43.866008    2004-06-20
# 101       Brooke Downs     C  180.350677  44.466420    2006-03-19
# 102       James Archer     C  163.550983  77.712212    2006-10-24
# 103     Kimberly Weiss     A  138.716450  58.393847    2005-12-23
# 104   Nicholas Stevens     B  185.189698  80.220606    2006-10-18
# 105    Natalie Daniels     A  180.376300  49.575043    2005-03-30
# 106      Monica Lawson     C  189.007582  98.174114    2006-11-07
# 107      Rachel Clarke     B  145.541867  38.314185    2004-05-11
# 108         Sarah Shaw     B  165.219758  93.355120    2005-07-12
# 109    Matthew Gregory     C  134.952631  45.940474    2005-03-17
# 110      Megan Herrera     C  189.853357  79.622058    2006-10-31
# 111    Stephen Francis     C  145.461921  86.924745    2007-04-24
# 112    Rebecca Leonard     C  131.954068  43.677392    2006-06-20
# ...

# %%
student_data.Name
# Out:
# 0          Alan Ferrell
# 1        Lindsay Coffey
# 2      Mitchell Bennett
# 3           Dawn Porter
# 4           Ashley Huff
#              ...
# 295       Shannon Hardy
# 296    Christopher Ware
# 297    Christina Thomas
# 298        Mark Esparza
# 299      William Foster
# Name: Name, Length: 300, dtype: object

# %%
student_data['Name']
# Out:
# 0          Alan Ferrell
# 1        Lindsay Coffey
# 2      Mitchell Bennett
# 3           Dawn Porter
# 4           Ashley Huff
#              ...
# 295       Shannon Hardy
# 296    Christopher Ware
# 297    Christina Thomas
# 298        Mark Esparza
# 299      William Foster
# Name: Name, Length: 300, dtype: object

# %%
student_data[['Name', 'Group']]
# Out:
#                  Name Group
# 0        Alan Ferrell     A
# 1      Lindsay Coffey     B
# 2    Mitchell Bennett     A
# 3         Dawn Porter     A
# 4         Ashley Huff     C
# ..                ...   ...
# 295     Shannon Hardy     B
# 296  Christopher Ware     A
# 297  Christina Thomas     C
# 298      Mark Esparza     C
# 299    William Foster     B
#
# [300 rows x 2 columns]

# %%
student_data.loc[3,["Name", "Group", "Height"]]
# Out:
# Name      Dawn Porter
# Group               A
# Height     160.481596
# Name: 3, dtype: object

# %%
student_data[student_data ["Group"] == 'A']
# Out:
#                  Name Group      Height     Weight Date_of_Birth  \
# 0        Alan Ferrell     A  131.433702  62.469138    2005-10-06
# 2    Mitchell Bennett     A  132.967250  93.559249    2005-08-30
# 3         Dawn Porter     A  160.481596  36.408254    2004-10-21
# 5      Clinton Dawson     A  173.524653  66.801124    2005-06-03
# 8         Tyler Meyer     A  133.860132  92.013826    2005-06-14
# ..                ...   ...         ...        ...           ...
# 276      Carol Palmer     A  185.948742  69.342926    2004-11-21
# 285   Michelle Carson     A  148.757399  76.580334    2006-06-15
# 286       Sarah Smith     A  151.540240  68.237031    2006-09-12
# 292       Ryan Arnold     A  138.557409  45.726217    2006-08-25
# 296  Christopher Ware     A  152.802949  44.157204    2006-08-31
#
#      Maths_Test_Score  Maths_Quiz_Score  Maths_Assignment_Score  \
# 0                  75                23                      96
# ...

# %%
student_data[
    (student_data["Group"]=='A') & (student_data["Height"]>160)
]
# Out:
#                    Name Group      Height     Weight Date_of_Birth  \
# 3           Dawn Porter     A  160.481596  36.408254    2004-10-21
# 5        Clinton Dawson     A  173.524653  66.801124    2005-06-03
# 16        Ruben Morales     A  164.569543  40.830899    2006-07-09
# 17    Dr. Paul Thompson     A  168.423981  62.205048    2004-12-10
# 21     Barbara Espinoza     A  175.763004  48.991579    2005-05-26
# 23            Tina Yang     A  183.077127  76.112455    2007-02-17
# 31             Amy Tran     A  182.486363  55.403956    2004-07-09
# 37           John Garza     A  188.048438  85.378761    2004-10-15
# 41        Alexander Fox     A  166.251512  56.331331    2006-07-19
# 42         Brian Harris     A  172.427313  57.523992    2005-12-24
# 46           David Leon     A  181.942900  85.597578    2006-02-27
# 51        Olivia Hughes     A  160.679096  36.983216    2007-04-18
# 52       Mark Hernandez     A  188.498185  43.124576    2006-10-08
# ...

# %%
student_data.groupby(["Group"]) ['Name'].count().reset_index()
# Out:
#   Group  Name
# 0     A    94
# 1     B    95
# 2     C   111

# %%
student_data.groupby(["Group"]) ['Weight'].sum().reset_index()
# Out:
#   Group       Weight
# 0     A  6101.885831
# 1     B  6414.941907
# 2     C  7574.692803

# %%
student_data.groupby(["Group"]) ['Maths_Quiz_Score'].mean().reset_index()
# Out:
#   Group  Maths_Quiz_Score
# 0     A         53.042553
# 1     B         52.936842
# 2     C         53.378378

# %%
min = student_data.groupby(["Group"]) ['Weight'].min().reset_index()
max = student_data.groupby(["Group"]) ['Weight'].max().reset_index()

# %%
min = student_data.groupby(["Group"]) ['Height'].min().reset_index()
max = student_data.groupby(["Group"]) ['Height'].max().reset_index()

# %%
science_test = student_data.groupby(["Group"]) ['Science_Test_Score'].mean().reset_index()
smallest_math_test = student_data.groupby(["Group"]) ['Maths_Test_Score'].min().loc['B']

# %%
student_data.loc[50, "Name"] = "Shawn Clark"

# %%
student_data.loc[50]
# Out:
# Name                           Shawn Clark
# Group                                    C
# Height                          144.945785
# Weight                           45.159664
# Date_of_Birth                   2006-06-08
# Maths_Test_Score                         2
# Maths_Quiz_Score                        67
# Maths_Assignment_Score                  43
# Science_Test_Score                      61
# Science_Quiz_Score                      36
# Science_Assignment_Score                 8
# Literature_Test_Score                   35
# Literature_Quiz_Score                   19
# Literature_Assignment_Score             26
# Name: 50, dtype: object

# %%
new_data = {
    "Name": ['Aldi', 'Tika', 'Michael Jung', 'Ronald'],
    "Group": ['A', 'B', 'A', 'A'],
    'Height': [147, 150, 184, 139],
    "Weight": [47, 39, 42,45]
}

new_dataframe = pd.DataFrame(new_data)
student_data = student_data._append(new_dataframe, ignore_index = True)

# %%
student_data.tail(20)
# Out:
#                  Name Group      Height     Weight Date_of_Birth  \
# 284    Andrew Solomon     C  159.019225  74.392341    2004-10-13
# 285   Michelle Carson     A  148.757399  76.580334    2006-06-15
# 286       Sarah Smith     A  151.540240  68.237031    2006-09-12
# 287       Joshua Bass     B  137.544748  48.370082    2004-06-08
# 288    Andrea Roberts     C  174.719137  79.828943    2006-06-07
# 289   Gerald Mitchell     B  166.906225  90.256385    2005-08-10
# 290  Nicholas Andrews     B  188.017360  61.279627    2005-04-28
# 291     Heather Olson     C  142.748380  86.072978    2007-04-19
# 292       Ryan Arnold     A  138.557409  45.726217    2006-08-25
# 293      Erica Pierce     C  157.149145  76.763277    2005-12-17
# 294     Dawn Martinez     B  188.462033  87.264918    2005-06-02
# 295     Shannon Hardy     B  169.467107  84.571455    2007-03-23
# 296  Christopher Ware     A  152.802949  44.157204    2006-08-31
# ...

# %%
student_data["Math_Score"] = (student_data["Maths_Test_Score"] + student_data["Maths_Quiz_Score"] + student_data["Maths_Assignment_Score"])/3

# %%
student_data = student_data.drop("Math_Score", axis=1)
student_data.tail()
# Out:
#                  Name Group      Height     Weight Date_of_Birth  \
# 295     Shannon Hardy     B  169.467107  84.571455    2007-03-23
# 296  Christopher Ware     A  152.802949  44.157204    2006-08-31
# 297  Christina Thomas     C  143.430767  99.893619    2004-06-10
# 298      Mark Esparza     C  186.765477  70.029551    2006-08-30
# 299    William Foster     B  153.790174  90.010683    2004-05-18
#
#      Maths_Test_Score  Maths_Quiz_Score  Maths_Assignment_Score  \
# 295                79                85                      96
# 296                24                65                      22
# 297                27                31                      44
# 298                10                39                      59
# 299                32                73                      60
#
#      Science_Test_Score  Science_Quiz_Score  Science_Assignment_Score  \
# 295                  75                  94                         9
# ...

# %%
student_data = student_data.drop(303)
student_data.tail()
# Out:
#                Name Group      Height     Weight Date_of_Birth  \
# 298    Mark Esparza     C  186.765477  70.029551    2006-08-30
# 299  William Foster     B  153.790174  90.010683    2004-05-18
# 300            Aldi     A  147.000000  47.000000           NaN
# 301            Tika     B  150.000000  39.000000           NaN
# 302    Michael Jung     A  184.000000  42.000000           NaN
#
#      Maths_Test_Score  Maths_Quiz_Score  Maths_Assignment_Score  \
# 298              10.0              39.0                    59.0
# 299              32.0              73.0                    60.0
# 300               NaN               NaN                     NaN
# 301               NaN               NaN                     NaN
# 302               NaN               NaN                     NaN
#
#      Science_Test_Score  Science_Quiz_Score  Science_Assignment_Score  \
# 298                 3.0                67.0                      15.0
# ...
